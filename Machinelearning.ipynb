# %% [markdown]
# <a href="https://colab.research.google.com/github/SathwikGuduguntla/Airplane_Mode/blob/main/Machinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#structure througth whitespace
#code runs from the top to buttom
#comments starts with the
# automatic type detection
int = 30
float = 12.3
str = "sathwik"
bool = True or False
print(int)
print(float)
print(str)
print(bool)

txt = 'hello world'
print(txt.upper())
